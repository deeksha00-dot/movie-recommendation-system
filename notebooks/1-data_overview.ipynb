# %% [markdown]
# ## data understanding

# %%
import pandas as pd
import numpy as np
import ast

# %%
movies = pd.read_csv("../movies_metadata.csv", low_memory=False)

credits = pd.read_csv("../credits.csv")

keywords = pd.read_csv("../keywords.csv")

ratings = pd.read_csv("../ratings_small.csv")

# %%
movies.sample(5)
# Out:
#        adult                              belongs_to_collection budget  \
# 4698   False  {'id': 41649, 'name': 'The Party Collection', ...      0
# 37691  False                                                NaN      0
# 8813   False  {'id': 14095, 'name': 'Barefoot Gen Collection...      0
# 19547  False                                                NaN      0
# 954    False                                                NaN      0
#
#                                                   genres homepage      id  \
# 4698   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN     166
# 37691  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...      NaN  329815
# 8813   [{'id': 16, 'name': 'Animation'}, {'id': 18, '...      NaN   14087
# 19547                     [{'id': 27, 'name': 'Horror'}]      NaN  110336
# 954    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN   39940
#
#          imdb_id original_language    original_title  \
# 4698   tt0082100                fr           La Boum
# 37691  tt4085084                fr          Maryland
# 8813   tt0085218                ja    Hadashi no Gen
# 19547  tt0050201                en  Blood of Dracula
# 954    tt0048491                en            Picnic
#
#                                                 overview  ... release_date  \
# 4698   Le Boum is the story of a 13-year-old French g...  ...   1980-01-01
# 37691  An ex-soldier with PTSD is hired to protect th...  ...   2015-09-30
# 8813   A powerful statement against war, Barefoot Gen...  ...   1983-07-21
# 19547  A medical examiner suspects a vampire might be...  ...   1957-11-01
# 954    The morning of a small town Labor Day picnic, ...  ...   1955-11-18
#
#        revenue runtime                           spoken_languages    status  \
# 4698       0.0   110.0  [{'iso_639_1': 'fr', 'name': 'Français'}]  Released
# 37691  39687.0   100.0  [{'iso_639_1': 'fr', 'name': 'Français'}]  Released
# 8813       0.0    83.0       [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 19547      0.0    68.0   [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 954        0.0   115.0   [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline             title  \
# 4698                                                 NaN         The Party
# 37691                                                NaN          Disorder
# 8813                                                 NaN      Barefoot Gen
# 19547           She Will GIVE YOU Nightmares...FOR EVER!  Blood of Dracula
# 954    Electrically attracted to each other...Overwhe...            Picnic
#
#        video vote_average vote_count
# 4698   False          6.4      225.0
# 37691  False          5.6       62.0
# 8813   False          7.6       29.0
# 19547  False          4.3        6.0
# 954    False          6.7       19.0
#
# [5 rows x 24 columns]

# %%
movies.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  str
#  1   belongs_to_collection  4494 non-null   str
#  2   budget                 45466 non-null  str
#  3   genres                 45466 non-null  str
#  4   homepage               7782 non-null   str
#  5   id                     45466 non-null  str
#  6   imdb_id                45449 non-null  str
#  7   original_language      45455 non-null  str
#  8   original_title         45466 non-null  str
#  9   overview               44512 non-null  str
#  10  popularity             45461 non-null  str
#  11  poster_path            45080 non-null  str
#  12  production_companies   45463 non-null  str
#  13  production_countries   45463 non-null  str
#  14  release_date           45379 non-null  str
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  str
#  18  status                 45379 non-null  str
#  19  tagline                20412 non-null  str
#  20  title                  45460 non-null  str
#  21  video                  45460 non-null  object
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: float64(4), object(1), str(19)
# memory usage: 8.3+ MB

# %%
movies.isnull().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
movies = movies[
    [
        "id",
        "title",
        "overview",
        "genres",
        "release_date",
        "vote_average",
        "vote_count",
        "popularity"
    ]
]
